# %%
for line in open("file.txt"):
    for word in line.split():
        if word.endswith('ing'):
            print(word)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-cd1b5e07612b> in <module>()
#       1
# ----> 2 for line in open("file.txt"):
#       3     for word in line.split():
#       4         if word.endswith('ing'):
#       5             print(word)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'

# %%
for line in open("01-file.txt"):
    for word in line.split():
        if word.endswith('ing'):
            print(word)
# Out:
# loving
# eclipsing
# comtemplating
# coding
# coding
# typing
# creating
# commaing
# innovating-waterskiing!amiling.panicking
# pythoning

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
texts()
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
text1.concordance("enormous")
# Out:
# Displaying 25 of 25 matches:
#  rolls over and over ; he rears his enormous head , and with wide expanded jaws
# ng clean over the craft , is in the enormous act of impaling himself upon the th
# of his embalmed head ; took out his enormous tobacco wallet , and groping under
#  which there was no mistaking . Two enormous wooden pots painted black , and sus
#  indefinite idea that a whale is an enormous creature of enormous power ; but I
#  a whale is an enormous creature of enormous power ; but I have ever found that
# nt had come ; they heard , too , an enormous wallowing sound as of fifty elephan
# ire interior of the sperm whale ' s enormous head consists . Though apparently t
# sea gods . In the first place , the enormous cutting tackles , among other ponde
# aning over to it , by reason of the enormous downward drag from the lower mast -
# ou would take the whole head for an enormous bass - viol , and these spiracles ,
# ...

# %%
text3.concordance("God")
# Out:
# Displaying 25 of 25 matches:
#  God created the heaven and the earth . An
#  face of the deep . And the Spirit of God moved upon the face of the waters . A
# ved upon the face of the waters . And God said , Let there be light : and there
#  be light : and there was light . And God saw the light , that it was good : an
# aw the light , that it was good : and God divided the light from the darkness .
# ded the light from the darkness . And God called the light Day , and the darkne
#  the morning were the first day . And God said , Let there be a firmament in th
# vide the waters from the waters . And God made the firmament , and divided the
# above the firmame and it was so . And God called the firmament Heaven . And the
# the morning were the second day . And God said , Let the waters under the heave
# the dry land appe and it was so . And God called the dry land Earth ; and the g
# gether of the waters called he Se and God saw that it was good . And God said ,
# ...

# %%
text4.dispersion_plot(["citizens", "democracy"])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:278: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
import numpy, matplotlib

# %%
import numpy
import matplotlib

# %%
text4.dispersion_plot(["citizens", "democracy"])

# %%
text4.dispersion_plot(["woman", "women", "child", "family", "families"])

# %%
text4.dispersion_plot(["woman", "women", "child", "family", "families", "children"])

# %%
(["woman", "women", "child", "family", "families", "children", "men"])
# Out:
# ['woman', 'women', 'child', 'family', 'families', 'children', 'men']

# %%
text4.dispersion_plot(["woman", "women", "child", "family", "families", "children", "men"])

# %%
total_words = len(text4)

# %%
set(text4)
# Out:
# {'intolerable',
#  'benevolent',
#  'incumbent',
#  'leading',
#  'respect',
#  '¡¦',
#  'Reflecting',
#  'cheering',
#  'misconstruction',
#  'virtuous',
#  'defaulters',
#  'conflicts',
#  'shadows',
#  'know',
#  'exceed',
#  'consecrates',
#  'advocated',
#  'industries',
#  'strives',
#  'sanguine',
#  'gold',
#  'settlement',
#  'termination',
#  'general',
#  'frontiers',
#  'disasters',
#  'flawed',
#  'carriers',
#  'lessen',
#  'temporarily',
#  'important',
#  'section',
#  'Moomaw',
#  'officers',
#  'movement',
#  'serves',
#  'dies',
#  'maximum',
#  'reproach',
#  'wavering',
#  'drafted',
#  'outlet',
#  'ask',
#  'triumph',
#  'belaboring',
#  'absolutely',
#  'overthrown',
#  'depend',
#  'indigent',
#  'sponsors',
#  'authority',
#  'Democrats',
#  'conspicuously',
#  'needing',
#  'Grant',
#  'walked',
#  'entailing',
#  'coherence',
#  'requirement',
#  'leaders',
#  'indispensable',
#  'departure',
#  'Magnifying',
#  'cure',
#  'meet',
#  'usurper',
# ...

# %%
num_unique_words = len(set(text4))

# %%
num_unique_words / total_words
# Out:
# 0.06692970116993173

# %%
total_words / num_unique_words
# Out:
# 14.941049825712529

# %% [markdown]
# #every 15th word is a unique word

# %%
text1.common_contexts(["woman", "man"])
# Out:
# old_, mortal_, a_' old_of old_'

# %%
text2.common_contexts(["woman", "man"])
# Out:
# a_in a_who young_who a_of a_as a_to young_of of_, a_whose young_.
# respectable_, charming_, young_, a_, other_in a_whom

# %%
sent7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c940be73f605> in <module>()
# ----> 1 sent7
#
# NameError: name 'sent7' is not defined

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
sent7
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.']

# %%
sorted(w for w in set(text1) if w.endswith('ableness'))
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted(term for term in set(text4) if 'gnt' in term)
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted(item for item in set(text6) if item.istitle())
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %%
sorted(item for item in set(sent7) if item.isdigit())
# Out:
# ['29', '61']

# %%
sorted(item for item in set(sent2) if item.isupper())
# Out:
# []

# %%
sorted(item for item in set(sent2) if item.islower())
# Out:
# ['been', 'family', 'had', 'in', 'long', 'of', 'settled']

# %%
sorted(item for item in set(text6) if item.isalpha())
# Out:
# ['A',
#  'ALL',
#  'AMAZING',
#  'ANIMATOR',
#  'ARMY',
#  'ARTHUR',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'BEDEVERE',
#  'BLACK',
#  'BORS',
#  'BRIDE',
#  'BRIDGEKEEPER',
#  'BROTHER',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
# ...

# %% [markdown]
# Return in sorted list if word in set(text7) contains '-' and 'index

# %%
sorted(w for w in set(text7) if '-' in w and 'index' in w)
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %% [markdown]
# Return in sorted list if word in set(text3) is a title (capitalised) and it's length is more than 10

# %%
sorted(wd for wd in set(text3) if wd.istitle() and len(wd) > 10)
# Out:
# ['Abelmizraim',
#  'Allonbachuth',
#  'Beerlahairoi',
#  'Canaanitish',
#  'Chedorlaomer',
#  'Girgashites',
#  'Hazarmaveth',
#  'Hazezontamar',
#  'Ishmeelites',
#  'Jegarsahadutha',
#  'Jehovahjireh',
#  'Kirjatharba',
#  'Melchizedek',
#  'Mesopotamia',
#  'Peradventure',
#  'Philistines',
#  'Zaphnathpaaneah']

# %%
(w for w in set(sent7) if not w.islower())
# Out:
# <generator object <genexpr> at 0x112e02fc0>

# %% [markdown]
# Return in sorted list if word in set(text7) is not lower case

# %%
sorted(w for w in set(sent7) if not w.islower())
# Out:
# [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']

# %% [markdown]
# Return in sorted list if word in set(text2) contains cie or cei

# %%
sorted(t for t in set(text2) if 'cie' in t or 'cei' in t)
# Out:
# ['ancient',
#  'ceiling',
#  'conceit',
#  'conceited',
#  'conceive',
#  'conscience',
#  'conscientious',
#  'conscientiously',
#  'deceitful',
#  'deceive',
#  'deceived',
#  'deceiving',
#  'deficiencies',
#  'deficiency',
#  'deficient',
#  'delicacies',
#  'excellencies',
#  'fancied',
#  'insufficiency',
#  'insufficient',
#  'legacies',
#  'perceive',
#  'perceived',
#  'perceiving',
#  'prescience',
#  'prophecies',
#  'receipt',
#  'receive',
#  'received',
#  'receiving',
#  'society',
#  'species',
#  'sufficient',
#  'sufficiently',
#  'undeceive',
#  'undeceiving']
